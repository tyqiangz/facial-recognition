# %%
import cv2
import time
import os

def video_to_frames(input_loc, output_loc):
    """Function to extract frames from input video file
    and save them as separate frames in an output directory.
    Args:
        input_loc: Input video file.
        output_loc: Output directory to save the frames.
    Returns:
        None
    """
    try:
        if not os.path.exists(output_loc):
            os.makedirs(output_loc)
    except OSError:
        print(OSError)
        
    # Log the time
    time_start = time.time()
    
    # Start capturing the feed
    cap = cv2.VideoCapture(input_loc)
    
    # Find the number of frames
    video_length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT)) - 1
    print ("Number of frames: ", video_length)
    
    count = 0
    
    print ("Converting video..\n")
    
    # Start converting the video
    while cap.isOpened():
        # Extract the frame
        ret, frame = cap.read()
    
        if not ret:
            continue
        # Write the results back to output location.
        cv2.imwrite(output_loc + "/%#05d.jpg" % (count+1), frame)
        count = count + 1
        # If there are no more frames left
        if (count > (video_length-1)):
            # Log the time again
            time_end = time.time()
            # Release the feed
            cap.release()
            # Print stats
            print ("Done extracting frames.\n%d frames extracted" % count)
            print ("It took %d seconds for conversion." % (time_end-time_start))
            break

# %%
# input_loc = '../videos/twoset_violin_eddy_chen/A pic that makes me forget my insecurities [YYb0w2Bl3RY].mp4'
# output_loc = '../images/twoset_violin_eddy_chen/A pic that makes me forget my insecurities [YYb0w2Bl3RY]'
# video_to_frames(input_loc, output_loc)

# %%
for personnel in os.listdir('../videos/'):
    print(personnel)
    
    for video_name in os.listdir('../videos/' + personnel):
        print(video_name)
        video_name_without_file_ext = video_name.split('.')[0]
        
        video_to_frames(input_loc=f'../videos/{personnel}/{video_name}', 
                        output_loc=f'../images/{personnel}/{video_name_without_file_ext}')
        
    print('-'*100)
# Out:
# cellist_laufey
# I Wish You Love - Laufey (Cover) [issStxOM5kw].mp4
# Number of frames:  2279
# Converting video..
#
# Done extracting frames.
# 2279 frames extracted
# It took 38 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# guitarist_andrew_foy
# Butter - BTS - Cover (Fingerstyle Guitar) [5ZWAVTBh6Vw].mp4
# Number of frames:  4190
# Converting video..
#
# Done extracting frames.
# 4190 frames extracted
# It took 75 seconds for conversion.
# I'll be in Germany! Musikmesse 2017 [hA-vFblLhEw].mp4
# Number of frames:  962
# Converting video..
#
# Done extracting frames.
# 962 frames extracted
# It took 4 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# guitarist_huang_xiao_xiang
# 周杰倫 - 告白氣球 (acoustic guitar solo) [JrOe25Yq6Gw].mp4
# Number of frames:  4624
# Converting video..
#
# Done extracting frames.
# 4624 frames extracted
# It took 10 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# guitarist_sungha_jung
# Sungha Jung speaks about his September tours! [0r3cfCZBIQs].mp4
# Number of frames:  1196
# Converting video..
#
# Done extracting frames.
# 1196 frames extracted
# It took 19 seconds for conversion.
# [정성하 연말 공연] Seoul & Busan 12.22 - 23 [wxAqFnWuB0c].mp4
# Number of frames:  1156
# Converting video..
#
# Done extracting frames.
# 1156 frames extracted
# It took 3 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# guitarist_sung_lee
# September cover [uLAfaMtaT3o].mp4
# Number of frames:  6685
# Converting video..
#
# Done extracting frames.
# 6685 frames extracted
# It took 109 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# influencer_daniel_tamago
# How I style my hair [K45mRG-fF1A].mp4
# Number of frames:  14999
# Converting video..
#
# Done extracting frames.
# 14999 frames extracted
# It took 251 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# influencer_ehiz_ufuah
# I don’t know how I come up with these looool #shorts [BZxsZ59EVwk].mp4
# Number of frames:  245
# Converting video..
#
# Done extracting frames.
# 245 frames extracted
# It took 0 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# influencer_jensen_tung
# I'M MOVING TO SINGAPORE - National University Of Singapore (NUS) Exchange [WWdiJWMyHS0].mp4
# Number of frames:  4548
# Converting video..
#
# Done extracting frames.
# 4548 frames extracted
# It took 76 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# influencer_khaby_lame
# 🤲🏿I will say Hi🙋🏿‍♂️to my community under comments👇🏾 and Thanks for the 115mln @tiktok loveU❤️ [HyG0Tx8jwh8].mp4
# Number of frames:  807
# Converting video..
#
# Done extracting frames.
# 807 frames extracted
# It took 0 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# musician_farrah
# Ex by Kiana Ledé (cover) [ba_Kr_zjVHA].mp4
# Number of frames:  5601
# Converting video..
#
# Done extracting frames.
# 5601 frames extracted
# It took 14 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# musician_george_collier
# That’s not a wrong note, you just lack confidence. (Jacob Collier) [meha_FCcHbo].mp4
# Number of frames:  3286
# Converting video..
#
# Done extracting frames.
# 3286 frames extracted
# It took 8 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# politician_baey_yam_keng
# Ask Me Anything With Baey Yam Keng, MP For Tampines GRC [fy5-oujex_U].mp4
# Number of frames:  12633
# Converting video..
#
# Done extracting frames.
# 12633 frames extracted
# It took 216 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# politician_dr_wan_azizah_wan_ismail
# My Minister series - Dr Wan Azizah Wan Ismail [rYD3VmGP8nM].mp4
# Number of frames:  12474
# Converting video..
#
# Done extracting frames.
# 12474 frames extracted
# It took 224 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# politician_goh_chok_tong
# Goh Chok Tong on pairing of Heng Swee Keat and Chan Chun Sing [Ut-AspMQ-2I].mp4
# Number of frames:  3433
# Converting video..
#
# Done extracting frames.
# 3433 frames extracted
# It took 59 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# politician_indranee_rajah
# Indranee Rajah on why she has to refer Workers' Party MP Raeesah Khan to the Committee of Privileges [1XwRQbINjUc].mp4
# Number of frames:  3908
# Converting video..
#
# Done extracting frames.
# 3908 frames extracted
# It took 22 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# politician_lee_bee_wah
# PAP's Lee Bee Wah turns epic storyteller during Budget 2018 debate [4AO48yEldHU].mp4
# Number of frames:  3854
# Converting video..
#
# Done extracting frames.
# 3854 frames extracted
# It took 38 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# politician_lee_hsien_loong
# Remarks by PM Lee Hsien Loong at the 16th Pacific Alliance Summit [u39lpp3hblI].mp4
# Number of frames:  7544
# Converting video..
#
# Done extracting frames.
# 7544 frames extracted
# It took 126 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# singer_jason_chen
# 小幸運 Chinese_English - Jason Chen [bMqKM9lqX7M].mp4
# Number of frames:  6357
# Converting video..
#
# Done extracting frames.
# 6357 frames extracted
# It took 16 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# singer_lin_jun_jie
# JJ Lin _ Mothership Instagram Asks [mSEk7zoNREo].mp4
# Number of frames:  7935
# Converting video..
#
# Done extracting frames.
# 7935 frames extracted
# It took 134 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# singer_zhou_hua_jian
# 周华健跨年晚会演唱经典武侠剧主题曲串烧，致敬金庸先生，真的好听又感人 [5HuiYg37m_4].mp4
# Number of frames:  12007
# Converting video..
#
# Done extracting frames.
# 12007 frames extracted
# It took 31 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# singer_zhou_hua_jian_lookalike
# Kembar dgn Emil Chou _ Wakin Chou _ 周華健(Zhou Hua Jian) [XV-PT1XLsEE].mp4
# Number of frames:  916
# Converting video..
#
# Done extracting frames.
# 916 frames extracted
# It took 0 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# twoset_violin_brett_yang
# Bae reveal [vp9-V-Q5mwQ].mp4
# Number of frames:  362
# Converting video..
#
# Done extracting frames.
# 362 frames extracted
# It took 2 seconds for conversion.
# When the conductor starts yelling at a section [oaHmMHLZroo].mp4
# Number of frames:  191
# Converting video..
#
# Done extracting frames.
# 191 frames extracted
# It took 1 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# twoset_violin_eddy_chen
# A pic that makes me forget my insecurities [YYb0w2Bl3RY].mp4
# Number of frames:  306
# Converting video..
#
# Done extracting frames.
# 306 frames extracted
# It took 1 seconds for conversion.
# When your friend asks if you want to get boba [C0E10wIwxlA].mp4
# Number of frames:  232
# Converting video..
#
# Done extracting frames.
# 232 frames extracted
# It took 1 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# youtuber_davie504
# this is the hardest instrument ever [8ToJAXweDJY].mp4
# Number of frames:  598
# Converting video..
#
# Done extracting frames.
# 598 frames extracted
# It took 3 seconds for conversion.
# When You Find Your Soulmate #Shorts [ay9cqTg53nU].mp4
# Number of frames:  917
# Converting video..
# Done extracting frames.
# 917 frames extracted
# It took 5 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# youtuber_prozd
# games that think more gameplay mechanics equals more fun [W1ZKcZbi1rg].mp4
# Number of frames:  1544
# Converting video..
#
# Done extracting frames.
# 1544 frames extracted
# It took 27 seconds for conversion.
# going from cutscene graphics to in-game graphics [JnX42OHnuLA].mp4
# Number of frames:  408
# Converting video..
#
# Done extracting frames.
# 408 frames extracted
# It took 6 seconds for conversion.
# ----------------------------------------------------------------------------------------------------
# youtuber_steven_he
# When Asians get a B in Geography [7BevacgFU7U].mp4
# Number of frames:  1445
# Converting video..
#
# Done extracting frames.
# 1445 frames extracted
# It took 23 seconds for conversion.
# ----------------------------------------------------------------------------------------------------

# %%
# for personnel in os.listdir('../videos/'):
    
#     for video_name in os.listdir('../videos/' + personnel):
#         video_name_without_file_ext = video_name.split('.')[0]
        
#         if len(os.listdir(f'../images/{personnel}/{video_name_without_file_ext}')) == 0:
#             print(personnel)
#             print(video_name)
#             video_to_frames(input_loc=f'../videos/{personnel}/{video_name}', 
#                             output_loc=f'../images/{personnel}/{video_name_without_file_ext}')
        
#             print('-'*100)
