# %% [markdown]
# # Facial Detection
#
# Using Python package from https://github.com/ageitgey/face_recognition
#
# Given an image, find all the locations (pixel-wise) of the faces, if any.

# %%
import face_recognition
from matplotlib import pyplot as plt

# %% [markdown]
# Load the image containing faces

# %%
image = face_recognition.load_image_file("../images/many-asian-male-faces.jpg")

# %% [markdown]
# Plot the image

# %%
plt.figure(figsize = (20,10))
plt.imshow(image)
plt.show()

# %% [markdown]
# Begin facial recognition

# %%
face_locations = face_recognition.face_locations(image)

print("I found {} face(s) in this photograph.".format(len(face_locations)))
# Out:
# I found 16 face(s) in this photograph.

# %% [markdown]
# Plot all the faces

# %%
for face_location in face_locations:

    # Print the location of each face in this image
    top, right, bottom, left = face_location
    print("A face is located at pixel location Top: {}, Left: {}, Bottom: {}, Right: {}".format(top, left, bottom, right))

    # You can access the actual face itself like this:
    face_image = image[top:bottom, left:right]
    plt.imshow(face_image)
    plt.show()
# Out:
# A face is located at pixel location Top: 118, Left: 97, Bottom: 304, Right: 283
# A face is located at pixel location Top: 1233, Left: 118, Bottom: 1419, Right: 304
# A face is located at pixel location Top: 490, Left: 159, Bottom: 676, Right: 345
# A face is located at pixel location Top: 1233, Left: 469, Bottom: 1419, Right: 655
# A face is located at pixel location Top: 882, Left: 97, Bottom: 1068, Right: 283
# A face is located at pixel location Top: 490, Left: 469, Bottom: 676, Right: 655
# A face is located at pixel location Top: 98, Left: 489, Bottom: 284, Right: 675
# A face is located at pixel location Top: 1233, Left: 1212, Bottom: 1419, Right: 1398
# A face is located at pixel location Top: 98, Left: 1191, Bottom: 284, Right: 1377
# A face is located at pixel location Top: 93, Left: 811, Bottom: 316, Right: 1034
# A face is located at pixel location Top: 885, Left: 464, Bottom: 1108, Right: 687
# A face is located at pixel location Top: 511, Left: 1232, Bottom: 696, Right: 1418
# A face is located at pixel location Top: 885, Left: 835, Bottom: 1108, Right: 1058
# A face is located at pixel location Top: 511, Left: 799, Bottom: 696, Right: 985
# A face is located at pixel location Top: 861, Left: 1212, Bottom: 1047, Right: 1398
# A face is located at pixel location Top: 1268, Left: 838, Bottom: 1423, Right: 992
